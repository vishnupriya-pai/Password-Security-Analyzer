# %%
import string
def  check_password(password):
 score=0
 feedback=[]
#Check length
if len(password)>=12:
   score +=1
   feedback.append("✓ Password length is greater than 12 characters.")
else 
   feedback.append("✗ Password length should be greater than 12 characters.")

#Check for lowercase letters
if any(char.islower(password)):
   score +=1
   feedback.append("✓ Password contains lowercase letters.")
else:
   feedback.append("✗ Password should contain lowercase letters.")

#Check for uppercase letters
if any(char.isupper(password)):
   score +=1
   feedback.append("✓ Password contains uppercase letters.")
